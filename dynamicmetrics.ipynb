# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import Image
from IPython.core.display import HTML
from termcolor import colored, cprint
from IPython.display import display, HTML
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np            # Data manipulation
import pandas as pd           # Dataframe manipulatio 
import matplotlib.pyplot as plt # For graphics
import matplotlib.path as mpath
import plotly

plotly.tools.set_credentials_file(username='RayyanAnsari', api_key='bmmXMgYcnUFHZrAcEW4d')

import plotly.plotly as py
import plotly.graph_objs as go

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from plotly.widgets import GraphWidget



hold=0

def h(Scale,Define_Metric):
    

    if Define_Metric=='Click_Through_Rate':
        
        #=['Number_of_InPerson_Consults','Average_Response_Time','Number of Active HPs','Drop off Rate']
        xx=Scale
        dor=30-(xx*2)
        yy=[(xx*5)+1 , 100/xx, int(xx*0.9) , dor]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]>=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
        
        
        if yy[2]<=4:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        
            
        if yy[3]>=20:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        
        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['Number_of_InPerson_Consults','Average_Response_Time','Number of Active HPs','Drop off Rate'],
                x=x,
                #y=y,
                #text=x,
                #textposition = 'auto',
                orientation = 'h',
                text=x,
                textposition = 'auto',
                
                marker=dict(
                color=color.tolist(),
                    
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.8
        )
                
            ]

            layout = go.Layout(
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
                
            #iplot(data, filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)


        

           
        
    if Define_Metric=='Average_Response_Time':
        
        #['Number_of_InPerson_Consults','Click_Through_Rate','Number of Active HPs','Drop off Rate']

        xx=Scale  
        yy=[int(62-(6*xx)) , int(54-(5*xx)), 10-xx , xx*5]
       
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]<=5:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=25:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
            
#         color[yy[1]>20]='rgb(0,255,0)'
        
        
#         color[y[0]<=20]='rgb(255,0,0)'
#         color[y[0]>20]='rgb(0,255,0)'
   
        
        def update_plot(xx):
            data = [go.Bar(
                y=['Number_of_InPerson_Consults','Click_Through_Rate','Number of Active HPs','Drop off Rate'],
                x=x,
                
                 orientation = 'h',   
                 text=x,
                 textposition = 'auto',
                marker=dict(
                    
                color=color.tolist(),
                    
                    
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.8
        )
                
            ]

            layout = go.Layout(
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            
            
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
       
        
    if Define_Metric=='Number_of_InPerson_Consults':
        
        #['Click_Through_Rate','Average_Response_Time','Number of Active HPs','Drop off Rate']
        xx=Scale
        yy=[(xx*5)-2 , 80-(7*xx), xx-1, 35-(3*xx)]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]>=40:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]<=5:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=18:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['Click_Through_Rate','Average_Response_Time','Number of Active HPs','Drop off Rate'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.8
        )
                
            ]
            
            layout = go.Layout(
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        
        
        
    if Define_Metric=='Number of Active HPs':
        #['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Drop off Rate']
        xx=Scale
        yy=[(xx*5)+1 , (xx*6)-2, 80-(7*xx), 35-(3*xx) ]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]>=45:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=18:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Drop off Rate'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.8
        )
                
            ]
            
            layout = go.Layout(
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        
    if Define_Metric=='Drop off Rate':
        
        #x=['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Number of Active HPs']
        
        xx=Scale
        yy=[int(62-(6*xx)) , int(54-(5*xx)), (xx-1)*10, 10-xx ]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]>=45:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]<=5:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Number of Active HPs'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.8
        )
                
            ]
            
            layout = go.Layout(
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
    return(0)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# <figure><img src="https://github.com/RayGen92/nbinteract-tutorial/blob/master/wecudospic.png?raw=true" width="150" height="150" align="right"/><figcaption><font size="6" color="blue">DYNAMIC BUSINESS METRICS</font></figcaption></figure>

# %%
interact(h,Scale=(1,10,1),Define_Metric=['Click_Through_Rate','Average_Response_Time','Number_of_InPerson_Consults','Number of Active HPs','Drop off Rate'])
# Out:
# interactive(children=(IntSlider(value=5, description='Scale', max=10, min=1), Dropdown(description='Define_Met…
# <function __main__.h(Scale, Define_Metric)>

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
##E3F6FF
from IPython.core.display import HTML
HTML("""
<style>
#notebook-container {
    padding: 15px;
    background-color: #e8e8e8;
    min-height: 0;
    -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
    box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
}
.notebook_app {
    background-color: darkblue;
}
#header{
background-color: lightgray;
}
#notebook_name.filename{

color:DarkBlue;
font-size:200%;
}
body #header{
background-color:lightgray;
}
</style>
""")
# Out:
# <style>
# #notebook-container {
#     padding: 15px;
#     background-color: #e8e8e8;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
# }
# .notebook_app {
#     background-color: darkblue;
# }
# #header{
# background-color: lightgray;
# }
# #notebook_name.filename{
#
# color:DarkBlue;
# font-size:200%;
# }
# body #header{
# background-color:lightgray;
# }
# </style>
