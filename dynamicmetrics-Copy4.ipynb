# %%
#


































#

# %% [markdown]
# <figure><img src="https://github.com/RayGen92/nbinteract-tutorial/blob/master/wecudospic.png?raw=true" width="80" height="80" align="right"/><figcaption><font size="6" color="blue">DYNAMIC BUSINESS METRICS</font></figcaption></figure>

# %%
from IPython.display import Image
from IPython.core.display import HTML
from termcolor import colored, cprint
from IPython.display import display, HTML
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np            # Data manipulation
import pandas as pd           # Dataframe manipulatio 
import matplotlib.pyplot as plt # For graphics
import matplotlib.path as mpath
import plotly

plotly.tools.set_credentials_file(username='RayyanAnsari', api_key='bmmXMgYcnUFHZrAcEW4d')

import plotly.plotly as py
import plotly.graph_objs as go

from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from plotly.widgets import GraphWidget

import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, CategoriesOptions
from watson_developer_cloud.natural_language_understanding_v1 import Features, SentimentOptions
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EntitiesOptions, KeywordsOptions

natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    iam_apikey="qs7JHxJOKs5LO21AJ0lZaO4_c4UT7R1f-sEoq5cCtNFw",
    url='https://gateway-syd.watsonplatform.net/natural-language-understanding/api'
)



hold=0

def h(Scale,Metric,texts):
    
    response = natural_language_understanding.analyze(
    text='Enter sample text here' + str(texts),
       #'Can we please reschule our appointment, im not feeling well'
    
#       features=Features(
#     entities=EntitiesOptions(
#       emotion=False,
#       sentiment=True,
#       limit=1),
#     )).get_result()
    features=Features(sentiment=SentimentOptions())).get_result()

    
    
    checkrate=response['sentiment']['document']['score']

    
    
    #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/wecudospic.png?raw=true", width=150, height=150))
    
    
    if Metric=='Click Through Rate':
        
        #cprint("Min Scale=__ / Max Scale=___", 'blue')
        
        #=['Number_of_InPerson_Consults','Average_Response_Time','Number of Active HPs','Drop off Rate']
        xx=Scale
        dor=30-(xx*2)
        yy=[(xx*5)+1 , int(100/xx), int(xx*0.9) , dor]
        
        #z=[str((xx*5)+1)+'test' , str(int(100/xx))+'t2', str(int(xx*0.9))+'t3' , str(dor)]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]>=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
        
        
        if yy[2]<=4:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        
            
        if yy[3]>=20:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        
        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['In Person Consults','Avg. Response Time (min)','Number of Active HPs','Drop off Rate (%)'],
                x=x,
                #y=y,
                #text=x,
                #textposition = 'auto',
                orientation = 'h',
                text=x,
                textposition = 'auto',
                
                marker=dict(
                color=color.tolist(),
                    
                line=dict(
                    color='rgb(8,48,107)',
                    width=5
                    
                ),
            ),
            opacity=0.7
        )
                
            ]

            layout = go.Layout(title='Aggregated by Month',
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=220,
        r=30,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
                
            #iplot(data, filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=400, height=400))

        if xx<4 and checkrate<=0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        
        elif xx<4 and checkrate>0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        
        
        elif xx>=4 and xx<=6 and checkrate<-0.25:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        
        elif xx>=4 and xx<=6 and checkrate<=0.25 and checkrate>=-0.25:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        elif xx>=4 and xx<=6 and checkrate>0.25:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))    
        
        
        
        elif xx>6 and checkrate<=0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        else:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=350, height=350))

        

           
        
    if Metric=='Average Response Time':
        
        #cprint("      Min Scale=__ / Max Scale=___", 'blue')
        
        #['Number_of_InPerson_Consults','Click_Through_Rate','Number of Active HPs','Drop off Rate']

        xx=Scale  
        yy=[int(62-(6*xx)) , int(54-(5*xx)), 10-xx , xx*5]
       
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]<=5:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=25:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
            
#         color[yy[1]>20]='rgb(0,255,0)'
        
        
#         color[y[0]<=20]='rgb(255,0,0)'
#         color[y[0]>20]='rgb(0,255,0)'
   
        
        def update_plot(xx):
            data = [go.Bar(
                y=['In Person Consults','Click Through Rate (%)','Number of Active HPs','Drop off Rate (%)'],
                x=x,
                
                 orientation = 'h',   
                 text=x,
                 textposition = 'auto',
                marker=dict(
                    
                color=color.tolist(),
                    
                    
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.7
        )
                
            ]

            layout = go.Layout(title='Aggregated by Month',
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            
            
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=400, height=400))

        if xx>=7 and checkrate<=0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        elif xx>=7 and checkrate>0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        
        elif xx>=4 and xx<=6 and checkrate<=0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        
        elif xx>=4 and xx<=6 and checkrate<=0.25 and checkrate>=-0.25:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        elif xx>=4 and xx<=6 and checkrate>0.25:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        
        
        elif xx<4 and checkrate<=0:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        else:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/responsepic.PNG?raw=true",width=300, height=300))

        
    if Metric=='In Person Consults':
        
        #cprint("      Min Scale=__ / Max Scale=___", 'blue')
        
        #['Click_Through_Rate','Average_Response_Time','Number of Active HPs','Drop off Rate']
        xx=Scale
        yy=[(xx*5)-2 , 80-(7*xx), xx-1, 35-(3*xx)]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]>=40:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]<=5:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=18:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['Click Through Rate (%)','Avg. Response Time (min)','Number of Active HPs','Drop off Rate (%)'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.7
        )
                
            ]
            
            layout = go.Layout(title='Aggregated by Month',
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=400, height=400))

        if xx<4:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        elif xx>=4 and xx<=6:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        else:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/ipc.PNG?raw=true",width=300, height=300))

        
        
        
    if Metric=='Number of Active HPs':
        
        #cprint("      Min Scale=__ / Max Scale=___", 'blue')
        #['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Drop off Rate']
        xx=Scale
        yy=[(xx*5)+1 , (xx*6)-2, 80-(7*xx), 35-(3*xx) ]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]>=45:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]>=18:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['In Person Consults','Click Through Rate (%)','Avg. Response Time (min)','Drop off Rate (%)'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.7
        )
                
            ]
            
            layout = go.Layout(title='Aggregated by Month',
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=400, height=400))

        if xx<4:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        elif xx>=4 and xx<=6:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        else:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/hppic.PNG?raw=true",width=300, height=300))

        
    if Metric=='Drop off Rate':
        
        #cprint("      Min Scale=__ / Max Scale=___", 'blue')
        
        #x=['Number_of_InPerson_Consults','Click_Through_Rate','Average_Response_Time','Number of Active HPs']
        
        xx=Scale
        yy=[int(62-(6*xx)) , int(54-(5*xx)), (xx-1)*10, 10-xx ]
        
        x=np.asarray(yy)

        color=np.array(['rgb(255,255,255)']*x.shape[0])

        
       
        
        if yy[1]<=20:
            color[1]='rgb(255,0,0)'
            
        else:
            color[1]='rgb(0,255,0)'
            
        if yy[0]<=20:
            color[0]='rgb(255,0,0)'
            
        else:
            color[0]='rgb(0,255,0)'
            
        if yy[2]>=45:
            color[2]='rgb(255,0,0)'
            
        else:
            color[2]='rgb(0,255,0)'
            
        if yy[3]<=5:
            color[3]='rgb(255,0,0)'
            
        else:
            color[3]='rgb(0,255,0)'
        

        
        def update_plot(xx):
            data = [go.Bar(
                
                y=['In Person Consults','Click Through Rate (%)','Average Response Time (min)','Number of Active HPs'],
                x=x,
                 
                 orientation = 'h',
                 text=x,
                 textposition = 'auto',
                marker=dict(
                color=color.tolist(),
                line=dict(
                    color='rgb(8,48,107)',
                    width=5),
            ),
            opacity=0.7
        )
                
            ]
            
            layout = go.Layout(title='Aggregated by Month',
        autosize=True,
    width=500,
    height=400,
                
        margin=dict(
        l=200,
        r=10,
        b=50,
        t=50,
        pad=2
    )
            )
     

    

            fig = go.Figure(data=data, layout=layout)
            iplot(fig, filename='size-margins')
            #iplot(data,filename='bar-direct-labels', show_link=False)
        
        update_plot(xx)
        
        display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/bigtable.PNG?raw=true",width=400, height=400))

        if xx>=7:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic1.PNG?raw=true",width=350, height=350))
        elif xx>=4 and xx<=6:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic2.PNG?raw=true",width=350, height=350))
        else:
            display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/tic3.PNG?raw=true",width=350, height=350))
        
        #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/droppic.PNG?raw=true",width=300, height=300))

        
    #display(Image(url= "https://github.com/RayGen92/nbinteract-tutorial/blob/master/wecudospic.png?raw=true", width=500, height=500))
    
    return(None)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
interact_manual(h,Scale=(1,10,1),Metric=['Click Through Rate','Average Response Time','In Person Consults','Number of Active HPs','Drop off Rate'],texts='Enter sample text!');
# Out:
# interactive(children=(IntSlider(value=5, description='Scale', max=10, min=1), Dropdown(description='Metric', o…

# %%
# from IPython.display import HTML
# HTML('''<script>
# code_show=true; 
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# } 
# $( document ).ready(code_toggle);
# </script>

# code <a href="javascript:code_toggle()">here</a>.''')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
##E3F6FF
from IPython.core.display import HTML
HTML("""
<style>
#notebook-container {
    padding: 15px;
    background-color: #e8e8e8;
    min-height: 0;
    -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
    box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
}
.notebook_app {
    background-color: darkblue; 

}
#header{
background-color: lightgray;
}
#notebook_name.filename{

color:DarkBlue;
font-size:200%;
}
body #header{
background-color:lightgray;
}
</style>
'''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script><a href="javascript:code_toggle()">code</a>.'''

""")
# Out:
# <style>
# #notebook-container {
#     padding: 15px;
#     background-color: #e8e8e8;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
# }
# .notebook_app {
#     background-color: darkblue;
#
# }
# #header{
# background-color: lightgray;
# }
# #notebook_name.filename{
#
# color:DarkBlue;
# font-size:200%;
# }
# body #header{
# background-color:lightgray;
# }
# </style>
# '''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script><a href="javascript:code_toggle()">code</a>.'''

# %%
CSS = """
.output {
    
    flex-direction: row;
    
    
}

"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#
#     flex-direction: row;
#
#
# }
#
# </style>
